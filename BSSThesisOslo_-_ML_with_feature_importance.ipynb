# %%
import scipy
import numpy
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU
import pandas as pd
import numpy as np

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

from matplotlib import pyplot as plt
from IPython.core.pylabtools import figsize

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()
import seaborn as sns

# %%
df = pd.read_csv("08.06.22.csv", index_col = 0)

# %% [markdown]
# Split into training and test data

# %%
train_size = int(len(df)*0.8)
train_dataset, test_dataset = df.iloc[:train_size], df.iloc[train_size:]

# %% [markdown]
# Plot training and test data

# %%
# Plot train and test data
plt.figure(figsize = (10, 6))
#plt.figure(figsize = (15, 6))

#Line width
lw = 0.6

sns.lineplot(x = train_dataset.index, y = train_dataset.Users, linewidth = lw)
sns.lineplot(x = test_dataset.index, y = test_dataset.Users, linewidth = lw)
plt.xlabel('Time (hour)')
plt.ylabel('Users')
plt.legend(['Train set', 'Test set'], loc='upper right')
plt.xlabel('Time period (4 hours)')

print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)
# Out:
# Dimension of train data:  (4225, 31)
# Dimension of test data:  (1057, 31)

# %%
# Plot train and test data
sns.set(rc={'figure.figsize':(10,6)})
#plt.figure(figsize = (15, 6))

#Size of circles
Size = 10

sns.scatterplot(x = train_dataset.index, y = train_dataset.Users, s = Size)
sns.scatterplot(x = test_dataset.index, y = test_dataset.Users, s = Size)
plt.xlabel('Time (hour)')
plt.ylabel('Users')
plt.legend(['Train set', 'Test set'], loc='upper right')
plt.xlabel('Time period (4 hours)')

print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)
# Out:
# Dimension of train data:  (4225, 31)
# Dimension of test data:  (1057, 31)

# %%
# Split train data to X and y
X_train = train_dataset.drop(['Users'], axis = 1)
y_train = train_dataset.loc[:,['Users']]

# Split test data to X and y
X_test = test_dataset.drop(['Users'], axis = 1)
y_test = test_dataset.loc[:,['Users']]

# %%
# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))

# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)

# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)

# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# %%
# Create a 3D input
def create_dataset (X, y, time_steps = 1):
    Xs, ys = [], []
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])
    return np.array(Xs), np.array(ys)

#Have set time steps to 12, equivalent of two days
TIME_STEPS = 12
X_test, y_test = create_dataset(test_x_norm, test_y_norm,   
                                TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm, 
                                  TIME_STEPS)
print('X_train.shape: ', X_test.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_train.shape)
# Out:
# X_train.shape:  (1045, 12, 30)
# y_train.shape:  (4213, 1)
# X_test.shape:  (1045, 12, 30)
# y_test.shape:  (4213, 1)

# %%
# Function for LSTM and GRU model
def create_model(units, m):
    model = Sequential()
    model.add(m (units = units, return_sequences = True,
                input_shape = [X_train.shape[1], X_train.shape[2]]))
    model.add(Dropout(0.2))
    initializer = tf.keras.initializers.GlorotUniform()
    model.add(m (units = units, kernel_initializer=initializer))
    #model.add(m (units = units))
    model.add(Dropout(0.2))
    model.add(Dense(units = 1, activation = "sigmoid"))
    
    #opt = keras.optimizers.Adam(learning_rate=0.01)
    #Compile model
    model.compile(loss='mae', optimizer="adam")
    return model

# GRU and LSTM
model_gru = create_model(64, GRU)
model_lstm = create_model(64, LSTM)

# %%
# Fitting LSTM and GRU
def fit_model(model):
    earlystopping  = keras.callbacks.EarlyStopping(monitor = 'val_loss',
   
   #The patience for early stopping is set to 20 as the validation and training loss tends to zig zag.
                                               patience = 20)
    
    #Epochs at 150 is not too high considering the batch_size, steps_per_epoch and timestep set earlier.
    #Early stopping is meant to prevent overfitting.
    history = model.fit(X_train, y_train, epochs = 150,  
                        validation_split = 0.2, batch_size = 64, 
                        callbacks = [earlystopping],
                        steps_per_epoch = 16)
    return history
history_lstm = fit_model(model_lstm)
history_gru = fit_model(model_gru)
# Out:
# Epoch 1/150
# 16/16 [==============================] - 4s 66ms/step - loss: 0.2272 - val_loss: 0.0818
# Epoch 2/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1376 - val_loss: 0.0817
# Epoch 3/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1225 - val_loss: 0.0823
# Epoch 4/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1157 - val_loss: 0.0905
# Epoch 5/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.1141 - val_loss: 0.0804
# Epoch 6/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.1081 - val_loss: 0.0830
# Epoch 7/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0959 - val_loss: 0.0960
# Epoch 8/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0836 - val_loss: 0.0879
# Epoch 9/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0678 - val_loss: 0.0900
# Epoch 10/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0728 - val_loss: 0.0790
# Epoch 11/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0630 - val_loss: 0.0754
# Epoch 12/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0647 - val_loss: 0.0826
# Epoch 13/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0617 - val_loss: 0.0852
# Epoch 14/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0625 - val_loss: 0.0749
# Epoch 15/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0598 - val_loss: 0.0800
# Epoch 16/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0584 - val_loss: 0.0686
# Epoch 17/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0577 - val_loss: 0.0712
# Epoch 18/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0582 - val_loss: 0.0692
# Epoch 19/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0504 - val_loss: 0.0635
# Epoch 20/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0578 - val_loss: 0.0928
# Epoch 21/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0541 - val_loss: 0.0650
# Epoch 22/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0538 - val_loss: 0.0712
# Epoch 23/150
# 16/16 [==============================] - 0s 22ms/step - loss: 0.0532 - val_loss: 0.0711
# Epoch 24/150
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0497 - val_loss: 0.0673
# Epoch 25/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0482 - val_loss: 0.0612
# Epoch 26/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0508 - val_loss: 0.0721
# Epoch 27/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0557 - val_loss: 0.0646
# Epoch 28/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0514 - val_loss: 0.0730
# Epoch 29/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0481 - val_loss: 0.0630
# Epoch 30/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0467 - val_loss: 0.0644
# Epoch 31/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0508 - val_loss: 0.0616
# Epoch 32/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0486 - val_loss: 0.0583
# Epoch 33/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0480 - val_loss: 0.0676
# Epoch 34/150
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0474 - val_loss: 0.0650
# Epoch 35/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0507 - val_loss: 0.0634
# Epoch 36/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0477 - val_loss: 0.0678
# Epoch 37/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0459 - val_loss: 0.0681
# Epoch 38/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0465 - val_loss: 0.0740
# Epoch 39/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0510 - val_loss: 0.0630
# Epoch 40/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0484 - val_loss: 0.0613
# Epoch 41/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0447 - val_loss: 0.0648
# Epoch 42/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0469 - val_loss: 0.0665
# Epoch 43/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0468 - val_loss: 0.0627
# Epoch 44/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0457 - val_loss: 0.0566
# Epoch 45/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0489 - val_loss: 0.0578
# Epoch 46/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0474 - val_loss: 0.0647
# Epoch 47/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0467 - val_loss: 0.0648
# Epoch 48/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0484 - val_loss: 0.0595
# Epoch 49/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0446 - val_loss: 0.0695
# Epoch 50/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0458 - val_loss: 0.0639
# Epoch 51/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0477 - val_loss: 0.0644
# Epoch 52/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0441 - val_loss: 0.0592
# Epoch 53/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0468 - val_loss: 0.0609
# Epoch 54/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0473 - val_loss: 0.0655
# Epoch 55/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0431 - val_loss: 0.0593
# Epoch 56/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0422 - val_loss: 0.0569
# Epoch 57/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0405 - val_loss: 0.0603
# Epoch 58/150
# 16/16 [==============================] - 0s 20ms/step - loss: 0.0450 - val_loss: 0.0652
# Epoch 59/150
# 16/16 [==============================] - 0s 21ms/step - loss: 0.0414 - val_loss: 0.0582
# Epoch 60/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0438 - val_loss: 0.0622
# Epoch 61/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0478 - val_loss: 0.0596
# Epoch 62/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0402 - val_loss: 0.0690
# Epoch 63/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0437 - val_loss: 0.0640
# Epoch 64/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0431 - val_loss: 0.0597
# Epoch 1/150
# 16/16 [==============================] - 4s 65ms/step - loss: 0.1943 - val_loss: 0.0781
# Epoch 2/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1337 - val_loss: 0.0784
# Epoch 3/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.1170 - val_loss: 0.0719
# Epoch 4/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.1117 - val_loss: 0.0704
# Epoch 5/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0983 - val_loss: 0.0612
# Epoch 6/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0864 - val_loss: 0.0452
# Epoch 7/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0700 - val_loss: 0.0485
# Epoch 8/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0683 - val_loss: 0.0474
# Epoch 9/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0685 - val_loss: 0.0423
# Epoch 10/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0629 - val_loss: 0.0459
# Epoch 11/150
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0653 - val_loss: 0.0449
# Epoch 12/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0580 - val_loss: 0.0426
# Epoch 13/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0633 - val_loss: 0.0426
# Epoch 14/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0614 - val_loss: 0.0432
# Epoch 15/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0595 - val_loss: 0.0399
# Epoch 16/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0613 - val_loss: 0.0407
# Epoch 17/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0611 - val_loss: 0.0447
# Epoch 18/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0581 - val_loss: 0.0452
# Epoch 19/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0582 - val_loss: 0.0516
# Epoch 20/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0592 - val_loss: 0.0446
# Epoch 21/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0591 - val_loss: 0.0426
# Epoch 22/150
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0570 - val_loss: 0.0428
# Epoch 23/150
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0557 - val_loss: 0.0397
# Epoch 24/150
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0555 - val_loss: 0.0416
# Epoch 25/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0589 - val_loss: 0.0438
# Epoch 26/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0558 - val_loss: 0.0450
# Epoch 27/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0533 - val_loss: 0.0440
# Epoch 28/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0543 - val_loss: 0.0398
# Epoch 29/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0570 - val_loss: 0.0420
# Epoch 30/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0519 - val_loss: 0.0423
# Epoch 31/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0554 - val_loss: 0.0424
# Epoch 32/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0524 - val_loss: 0.0402
# Epoch 33/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0535 - val_loss: 0.0403
# Epoch 34/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0566 - val_loss: 0.0413
# Epoch 35/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0529 - val_loss: 0.0407
# Epoch 36/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0522 - val_loss: 0.0423
# Epoch 37/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0503 - val_loss: 0.0421
# Epoch 38/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0553 - val_loss: 0.0418
# Epoch 39/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0516 - val_loss: 0.0398
# Epoch 40/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0539 - val_loss: 0.0437
# Epoch 41/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0511 - val_loss: 0.0428
# Epoch 42/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0521 - val_loss: 0.0394
# Epoch 43/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0498 - val_loss: 0.0421
# Epoch 44/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0502 - val_loss: 0.0386
# Epoch 45/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0479 - val_loss: 0.0412
# Epoch 46/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0502 - val_loss: 0.0404
# Epoch 47/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0489 - val_loss: 0.0398
# Epoch 48/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0503 - val_loss: 0.0390
# Epoch 49/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0503 - val_loss: 0.0403
# Epoch 50/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0492 - val_loss: 0.0424
# Epoch 51/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0490 - val_loss: 0.0407
# Epoch 52/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0494 - val_loss: 0.0393
# Epoch 53/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0464 - val_loss: 0.0399
# Epoch 54/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0458 - val_loss: 0.0389
# Epoch 55/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0481 - val_loss: 0.0403
# Epoch 56/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0482 - val_loss: 0.0426
# Epoch 57/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0486 - val_loss: 0.0429
# Epoch 58/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0477 - val_loss: 0.0398
# Epoch 59/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0488 - val_loss: 0.0414
# Epoch 60/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0445 - val_loss: 0.0453
# Epoch 61/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0496 - val_loss: 0.0394
# Epoch 62/150
# 16/16 [==============================] - 0s 18ms/step - loss: 0.0445 - val_loss: 0.0379
# Epoch 63/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0489 - val_loss: 0.0395
# Epoch 64/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0458 - val_loss: 0.0379
# Epoch 65/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0465 - val_loss: 0.0431
# Epoch 66/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0461 - val_loss: 0.0401
# Epoch 67/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0440 - val_loss: 0.0365
# Epoch 68/150
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0486 - val_loss: 0.0380
# Epoch 69/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0463 - val_loss: 0.0384
# Epoch 70/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0460 - val_loss: 0.0372
# Epoch 71/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0446 - val_loss: 0.0389
# Epoch 72/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0462 - val_loss: 0.0370
# Epoch 73/150
# 16/16 [==============================] - 0s 19ms/step - loss: 0.0468 - val_loss: 0.0398
# Epoch 74/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0445 - val_loss: 0.0366
# Epoch 75/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0472 - val_loss: 0.0412
# Epoch 76/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0447 - val_loss: 0.0409
# Epoch 77/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0442 - val_loss: 0.0373
# Epoch 78/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0438 - val_loss: 0.0373
# Epoch 79/150
# 16/16 [==============================] - 0s 16ms/step - loss: 0.0477 - val_loss: 0.0364
# Epoch 80/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0447 - val_loss: 0.0392
# Epoch 81/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0465 - val_loss: 0.0377
# Epoch 82/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0421 - val_loss: 0.0389
# Epoch 83/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0469 - val_loss: 0.0368
# Epoch 84/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0463 - val_loss: 0.0363
# Epoch 85/150
# 16/16 [==============================] - 0s 14ms/step - loss: 0.0447 - val_loss: 0.0365
# Epoch 86/150
# 16/16 [==============================] - 0s 15ms/step - loss: 0.0451 - val_loss: 0.0376
# Epoch 87/150
# 16/16 [==============================] - 0s 17ms/step - loss: 0.0436 - val_loss: 0.0397
# Epoch 88/150
# 16/16 [==============================] - 0s 23ms/step - loss: 0.0441 - val_loss: 0.0378
# Epoch 89/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0430 - val_loss: 0.0372
# Epoch 90/150
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0476 - val_loss: 0.0365
# Epoch 91/150
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0444 - val_loss: 0.0356
# Epoch 92/150
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0393 - val_loss: 0.0365
# Epoch 93/150
# 16/16 [==============================] - 1s 37ms/step - loss: 0.0466 - val_loss: 0.0397
# Epoch 94/150
# 16/16 [==============================] - 1s 36ms/step - loss: 0.0435 - val_loss: 0.0371
# Epoch 95/150
# 16/16 [==============================] - 1s 33ms/step - loss: 0.0463 - val_loss: 0.0350
# Epoch 96/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0414 - val_loss: 0.0369
# Epoch 97/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0428 - val_loss: 0.0360
# Epoch 98/150
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0444 - val_loss: 0.0369
# Epoch 99/150
# 16/16 [==============================] - 0s 30ms/step - loss: 0.0434 - val_loss: 0.0382
# Epoch 100/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0425 - val_loss: 0.0382
# Epoch 101/150
# 16/16 [==============================] - 1s 34ms/step - loss: 0.0432 - val_loss: 0.0381
# Epoch 102/150
# 16/16 [==============================] - 1s 35ms/step - loss: 0.0451 - val_loss: 0.0385
# Epoch 103/150
# 16/16 [==============================] - 0s 31ms/step - loss: 0.0447 - val_loss: 0.0388
# Epoch 104/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0424 - val_loss: 0.0389
# Epoch 105/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0438 - val_loss: 0.0354
# Epoch 106/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0424 - val_loss: 0.0374
# Epoch 107/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0406 - val_loss: 0.0383
# Epoch 108/150
# 16/16 [==============================] - 0s 29ms/step - loss: 0.0429 - val_loss: 0.0395
# Epoch 109/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0467 - val_loss: 0.0404
# Epoch 110/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0438 - val_loss: 0.0397
# Epoch 111/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0402 - val_loss: 0.0417
# Epoch 112/150
# 16/16 [==============================] - 0s 28ms/step - loss: 0.0458 - val_loss: 0.0387
# Epoch 113/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0450 - val_loss: 0.0394
# Epoch 114/150
# 16/16 [==============================] - 0s 27ms/step - loss: 0.0437 - val_loss: 0.0412
# Epoch 115/150
# 16/16 [==============================] - 0s 26ms/step - loss: 0.0439 - val_loss: 0.0381

# %%
# Plot train loss and validation loss
def plot_loss (history):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')
plot_loss (history_lstm)
plot_loss (history_gru)

# %%
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# %%
# Make prediction
def prediction(model):
    prediction = model.predict(X_test)
    prediction = scaler_y.inverse_transform(prediction)
    return prediction

prediction_lstm = prediction(model_lstm)
prediction_gru = prediction(model_gru)
# Plot true future vs prediction
def plot_future(prediction, y_test):
    plt.figure(figsize=(10, 6))
    range_future = len(prediction)
        
    plt.plot(np.arange(range_future), np.array(y_test), 
             label='True Future')
    
    plt.plot(np.arange(range_future),np.array(prediction),
            label='Prediction')
    
    plt.legend(loc='upper left')
    plt.xlabel('Time period (4 hours)')
    plt.ylabel('Bike users per time period')

plot_future(prediction_lstm, y_test)
plot_future(prediction_gru, y_test)

# %%
from prettytable import PrettyTable

def array_with_prediction(predictions, actual):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    rsquared = r2_score(actual, predictions)
    array = np.array([mae, rmse, rsquared])
    return array
###########################################################################
# Define a function to calculate MAE and RMSE
def evaluate_prediction(predictions, actual, model_name):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print('R-squared: {:.4f}'.format(r2_score(actual, predictions)))
    print('')

evaluate_prediction(prediction_lstm, y_test, 'LSTM')
evaluate_prediction(prediction_gru, y_test, 'GRU')
################################################################################
lstm = array_with_prediction(prediction_lstm, y_test)
gru = array_with_prediction(prediction_gru, y_test)
# Out:
# LSTM:
# Mean Absolute Error: 8.0415
# Root Mean Square Error: 12.3828
# R-squared: 0.6473
#
# GRU:
# Mean Absolute Error: 7.2130
# Root Mean Square Error: 11.3616
# R-squared: 0.7031

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn import metrics
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error


X = df.drop(columns = ['Users'], axis = 1)
y = df["Users"]


X_train,X_test,y_train,y_test = train_test_split(X.values,y,test_size=0.20,random_state=0)

clf = RandomForestRegressor(n_estimators=1000,
            oob_score=True)
clf.fit(X_train,y_train)
y_pred=clf.predict(X_test)

evaluate_prediction(y_pred, y_test, 'RF')
# Out:
# RF:
# Mean Absolute Error: 6.6219
# Root Mean Square Error: 10.2370
# R-squared: 0.8527

# %%
models = ["Metrics", "LSTM", "GRU", "RF"]
metrics = np.array(["MAE", "RMSE", "R-Squared"])

lstm = ["%.2f" % member for member in lstm]
gru = ["%.2f" % member for member in gru]
rf = array_with_prediction(y_pred, y_test)
rf = ["%.2f" % member for member in rf]

table = PrettyTable()

table.add_column(models[0], metrics)
table.add_column(models[1], lstm)
table.add_column(models[2], gru)
table.add_column(models[3], rf)


table
# Out:
# +-----------+-------+-------+-------+
# |  Metrics  |  LSTM |  GRU  |   RF  |
# +-----------+-------+-------+-------+
# |    MAE    |  8.04 |  7.21 |  6.62 |
# |    RMSE   | 12.38 | 11.36 | 10.24 |
# | R-Squared |  0.65 |  0.70 |  0.85 |
# +-----------+-------+-------+-------+

# %%
plot_future(y_pred, y_test)

# %%
y_pred = pd.DataFrame(y_pred)
y_test = pd.DataFrame(y_test)

# %% [markdown]
# Plot distribution of RF

# %%
y_train = y_train.to_frame()
y_test["Data"] = "Test set"
y_train["Data"] = "Train set"


y1_Train = y_train.sort_index().reindex(list(range(0, 5282)), fill_value = 0)
y1_Test = y_test.sort_index().reindex(list(range(0, 5282)), fill_value = 0)

# %%
print('Observations in train data: ', y_train.shape[0])
print('Observations in test data: ', y_test.shape[0])

#Linewidth
lw = 0.6

#sns.rugplot(x = 'index', y = 'Users', ax = ax, hue = 'Data', 
#            data = combined.reset_index())
fig, ax = plt.subplots(figsize=(12,6))
sns.lineplot(x = 'index', y = 'Users', ax = ax, 
            data = y1_Train.reset_index(),
            legend='brief', label= "Train set", linewidth = lw)
sns.lineplot(x = 'index', y = 'Users', ax = ax, 
            data = y1_Test.reset_index(),
            legend='brief', label= "Test set", linewidth = lw)
plt.xlabel('Time period (4 hours)')
#plt.fill_between(combined.index, combined.Users)
# Out:
# Observations in train data:  4225
# Observations in test data:  1057
# Text(0.5, 0, 'Time period (4 hours)')

# %%
vertical_stack = pd.concat([y_train, y_test], axis=0)
combined = vertical_stack.sort_index()

# %%
print('Observations in train data: ', y_train.shape[0])
print('Observations in test data: ', y_test.shape[0])

#Size of circles
size = 10

sns.set(rc={'figure.figsize':(10,6)})
fig, ax = plt.subplots(figsize=(12,6))
#sns.rugplot(x = 'index', y = 'Users', ax = ax, hue = 'Data', 
#            data = combined.reset_index())
g = sns.scatterplot(x = 'index', y = 'Users', ax = ax, hue = 'Data', 
            data = combined.reset_index(), s = size)
#plt.legend(labels = ['Train set', 'Test set'], loc='upper right')
#g.legend(['Train set', 'Test set'])
plt.xlabel('Time period (4 hours)')
plt.show(g)
# Out:
# Observations in train data:  4225
# Observations in test data:  1057

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
from matplotlib import pyplot as plt

# %%
from sklearn.ensemble import ExtraTreesClassifier
model = ExtraTreesClassifier(n_estimators=25)
model.fit(X, y)
importance = (clf.feature_importances_)

# %%
# linear regression feature importance
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot

# %%
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()

# %%
clf.feature_importances_
# Out:
# array([0.01831293, 0.27970691, 0.03996888, 0.04462098, 0.00704986,
#        0.00418565, 0.02112443, 0.02721939, 0.00506645, 0.00337824,
#        0.00499338, 0.00770684, 0.00909212, 0.00336038, 0.00039688,
#        0.00067111, 0.01017715, 0.0096392 , 0.00247929, 0.01559472,
#        0.00546157, 0.00683558, 0.00836324, 0.03764631, 0.27668444,
#        0.00393102, 0.09347214, 0.01914597, 0.01183521, 0.02187974])

# %%
sortclf = clf.feature_importances_.argsort()

# %%
plt.barh(X.columns[sortclf],clf.feature_importances_[sortclf])
# Out:
# <BarContainer object of 30 artists>

# %%
model.feature_importances_
# Out:
# array([0.05259647, 0.23567516, 0.04426684, 0.23498099, 0.02356424,
#        0.023401  , 0.02251168, 0.01949171, 0.02322842, 0.02231996,
#        0.02436529, 0.01134752, 0.00941558, 0.00572693, 0.0031582 ,
#        0.00337295, 0.00923979, 0.00832317, 0.00513205, 0.01230178,
#        0.00809995, 0.00992688, 0.00998287, 0.01073543, 0.00995961,
#        0.01325576, 0.10378985, 0.01309175, 0.01414923, 0.01258892])

# %%
sort = model.feature_importances_.argsort()
plt.barh(X.columns[sort], model.feature_importances_[sort])
plt.xlabel("Feature Importance")
# Out:
# Text(0.5, 0, 'Feature Importance')

# %%
sort
# Out:
# array([14, 15, 18, 13, 20, 17, 16, 12, 21, 24, 22, 23, 11, 19, 29, 27, 25,
#        28,  7,  9,  6,  8,  5,  4, 10,  2,  0, 26,  3,  1], dtype=int64)
